# %% [markdown]
# # Przygotwanie słownika

# %%
import collections
import os

UNK = "<unk>"
SOS = "<s>"
EOS = "</s>"

DATA_DIR = "./corpora" # sciezka do plików z danymi
PL_SENTENCES = "sentences_pl.txt" # plik z polskimi zdaniami
EN_SENTENCES = "sentences_en.txt" # plik z polskimi zdaniami
PL_VOCAB = "vocab_pl.txt" #plik z polskim słownikiem
EN_VOCAB = "vocab_en.txt" #plik z angielskim słownikiem

pl_sentences_path = os.path.join(DATA_DIR, PL_SENTENCES)
en_sentences_path = os.path.join(DATA_DIR, EN_SENTENCES)
pl_vocab_path = os.path.join(DATA_DIR, PL_VOCAB)
en_vocab_path = os.path.join(DATA_DIR, EN_VOCAB)

def createVocabulary(sentences_path, vocab_path, vocabulary_size = 50000):
    sentences_file = open(sentences_path, "r")
    sentences = sentences_file.read().replace('\n', ' ').replace('\r', '').split()
    count = [[UNK, -1], [SOS, -1], [EOS, -1]]
    count.extend(collections.Counter(sentences).most_common(vocabulary_size))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in sentences:
        index = dictionary.get(word, 0)
        if index == 0:  # dictionary['UNK']
            unk_count += 1
        data.append(index)
    count[0][1] = unk_count
    vocab = ''
    vocab_file = open(vocab_path, "w")
    for word in list(dictionary.keys()):
        vocab_file.write(word + "\n")
    vocab_file.close()
    sentences_file.close()
    
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reverse_dictionary
    
# createVocabulary(pl_sentences_path, pl_vocab_path)
# createVocabulary(en_sentences_path, en_vocab_path)

# %% [markdown]
# ## Przygotowanie embedingsów

# %% [markdown]
# ### Generowanie batchów

# %%
def generate_batch(batch_size, num_skips, skip_window, data, data_index):
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1  # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)  # pylint: disable=redefined-builtin
    if data_index + span > len(data):
        data_index = 0
        
    buffer.extend(data[data_index:data_index + span])
    data_index += span
    for i in range(batch_size // num_skips):
        context_words = [w for w in range(span) if w != skip_window]
        words_to_use = random.sample(context_words, num_skips)
        for j, context_word in enumerate(words_to_use):
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[context_word]
        if data_index == len(data):
            buffer.extend(data[0:span])
            data_index = span
        else:
            buffer.append(data[data_index])
            data_index += 1
    # Backtrack a little bit to avoid skipping words in the end of a batch
    data_index = (data_index + len(data) - span) % len(data)
    return batch, labels, data_index

# %% [markdown]
# ## Skip-gram model

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import tensorflow as tf
import numpy as np
import math
import random
from six.moves import xrange

def createEmbeddings(sentences_path, vocab_path, log_dir = DATA_DIR):
    data_index = 0
    data, count, dictionary, reverse_dictionary = createVocabulary(sentences_path, vocab_path)
    batch, labels, data_index = generate_batch(8, 2, 1, data, data_index)
    print(batch)
    for i in range(8):
        print(batch[i])
        print(reverse_dictionary[batch[i]])
        print(labels[i, 0])
        print(reverse_dictionary[labels[i, 0]])
        print(batch[i], reverse_dictionary[batch[i]], '->', labels[i, 0],
              reverse_dictionary[labels[i, 0]])
    vocabulary_size = len(dictionary)
    
    batch_size = 128
    embedding_size = 128  # Dimension of the embedding vector.
    skip_window = 1  # How many words to consider left and right.
    num_skips = 2  # How many times to reuse an input to generate a label.
    num_sampled = 64  # Number of negative examples to sample.
    learning_rate = 1.0 # learning rate
    num_steps = 100001 # ilość kroków


    valid_size = 16  # Random set of words to evaluate similarity on.
    valid_window = 100  # Only pick dev samples in the head of the distribution.
    valid_examples = np.random.choice(valid_window, valid_size, replace=False)

    graph = tf.Graph()

    with graph.as_default():

        with tf.name_scope('inputs'):
            train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
            train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
            valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

        with tf.device('/cpu:0'):
            # Look up embeddings for inputs.
            with tf.name_scope('embeddings'):
                embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
                embed = tf.nn.embedding_lookup(embeddings, train_inputs)

            with tf.name_scope('weights'):
                nce_weights = tf.Variable(
                    tf.truncated_normal([vocabulary_size, embedding_size],stddev=1.0 / math.sqrt(embedding_size))
                )
                
            with tf.name_scope('biases'):
                nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

        with tf.name_scope('loss'):
            loss = tf.reduce_mean(tf.nn.nce_loss(
                weights=nce_weights,
                biases=nce_biases,
                labels=train_labels,
                inputs=embed,
                num_sampled=num_sampled,
                num_classes=vocabulary_size
            ))

        tf.summary.scalar('loss', loss)
        with tf.name_scope('optimizer'):
            optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss)

        # normalizacja minibatcha
        norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
        normalized_embeddings = embeddings / norm
        valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
        similarity = tf.matmul(valid_embeddings, normalized_embeddings, transpose_b=True)

        # Merge all summaries.
        merged = tf.summary.merge_all()

        # Add variable initializer.
        init = tf.global_variables_initializer()

        # Create a saver.
        saver = tf.train.Saver()

    with tf.Session(graph=graph) as session:
        writer = tf.summary.FileWriter(log_dir, session.graph)

        # We must initialize all variables before we use them.
        init.run()
        print('Initialized')

        average_loss = 0
        for step in xrange(num_steps):
            batch_inputs, batch_labels, data_index = generate_batch(batch_size, num_skips, skip_window, data, data_index)
            feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

            run_metadata = tf.RunMetadata()

            _, summary, loss_val = session.run(
                [optimizer, merged, loss],
                feed_dict=feed_dict,
                run_metadata=run_metadata)
            average_loss += loss_val
            writer.add_summary(summary, step)

            #wizualizacja danych
            if step == (num_steps - 1):
                writer.add_run_metadata(run_metadata, 'step%d' % step)

            #average loss
            if step % 2000 == 0:
                if step > 0:
                    average_loss /= 2000
                print('Average loss at step ', step, ': ', average_loss)
                average_loss = 0

            if step % 10000 == 0:
                sim = similarity.eval()
                for i in xrange(valid_size):
                    valid_word = reverse_dictionary[valid_examples[i]]
                    top_k = 8  # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                    log_str = 'Nearest to %s:' % valid_word
                    for k in xrange(top_k):
                        close_word = reverse_dictionary[nearest[k]]
                        log_str = '%s %s,' % (log_str, close_word)
                    print(log_str)

        final_embeddings = normalized_embeddings.eval()

        # Write corresponding labels for the embeddings.
        with open(log_dir + '/metadata.tsv', 'w') as f:
            for i in xrange(vocabulary_size):
                f.write(reverse_dictionary[i] + '\n')

        # Save the model for checkpoints.
        saver.save(session, os.path.join(log_dir, 'model.ckpt'))

    writer.close()
    
createEmbeddings(pl_sentences_path, pl_vocab_path)
# Out:
# [ 874  874    0    0    5    5 2790 2790]
# 874
# ustne
# 0
# <unk>
# 874 ustne -> 0 <unk>
# 874
# ustne
# 3202
# zapytanie
# 874 ustne -> 3202 zapytanie
# 0
# <unk>
# 5
# na
# 0 <unk> -> 5 na
# 0
# <unk>
# 874
# ustne
# 0 <unk> -> 874 ustne
# 5
# na
# 0
# <unk>
# 5 na -> 0 <unk>
# 5
# na
# 2790
# sesję
# 5 na -> 2790 sesję
# 2790
# sesję
# 779
# pytań
# 2790 sesję -> 779 pytań
# 2790
# sesję
# 5
# na
# 2790 sesję -> 5 na
# Initialized
# Average loss at step  0 :  287.7437744140625
# Nearest to r: obermayr, nieodłącznie, cornillet, neutralne, mówić, leży, schematu, konstytucją,
# Nearest to de: rolandas, ciążą, nowością, ogólnodostępnej, marí, eliminować, obsługą, charles,
# Nearest to 2: przetwórcy, państwu, korygowania, imię, martina, zbywalne, religijnych, mikroprzedsiębiorstwo,
# Nearest to rozporządzenia: ursula, 8e, sole, suplementów, dystrybucją, wymagań, pe423778v0200, zwiększaniem,
# Nearest to decyzji: pe456997v0100, arktyki, rentowne, estońskim, interpretacja, zapadać, poniosły, trójstronny,
# Nearest to zakresie: odtwarzania, przyczyniającymi, oznaczenia, fonogramu, operacyjnym, paszportem, jonizujące, syropu,
# Nearest to przypadku: affect, ogłoszona, fernandez, pilnych, bankami, youth, filmach, spójniejsze,
# Nearest to których: 5622006, pozakontraktowego, pobiera, ira, wnioskami, kompromisowe, walutą, usługobiorcą,
# Nearest to komisji: regularnych, motywowania, uelastycznienie, beazley, znajdującej, odpływ, toczyć, 20°c,
# Nearest to rzecz: zgłosi, wykroczenia, logiczne, turystów, kr, sprawiedliwą, biologicznymi, systematycznej,
# Nearest to ustęp: instytucjonalnych, krasts, wfp, poprzednim, dyscyplinarnym, korupcję, składowymi, wrażliwych,
# Nearest to rady: podtytuł, rzadkich, krąg, rachunkowości, czystość, nakłania, wdrażające, activity,
# Nearest to przez: becsey, mechanizmowi, radości, totalitaryzm, etc, płatności, decyzję», sprawców,
# Nearest to 3: paradoksalnie, wręczona, prevent, jednoznaczny, powtórzenie, kolegialności, kwalifikowane, udokumentowane,
# Nearest to tym: dziewiąte, przystąpi, przewodu, lehtomäki, rodi, pomogłaby, samojezdnych, uznawany,
# Nearest to 4: przeciwdziałanie, zaginionych, ramowej–, razem, przewozowych, madlener, 1011, umożliwić,
# Average loss at step  2000 :  114.28145048427582
# Average loss at step  4000 :  53.28752485013008
# Average loss at step  6000 :  32.73428077125549
# Average loss at step  8000 :  21.786268224358558
# Average loss at step  10000 :  15.156945079535246
# Nearest to r: schematu, cornillet, konstytucją, posiedzenie, <unk>, zwraca, obejmującej, lizbony,
# Nearest to de: rolandas, charles, van, ekonomicznospołeczny, władzom, morza, silviu, stronami,
# Nearest to 2: państwu, religijnych, stosowaniu, charakter, martina, casaca, imię, regulacyjnej,
# Nearest to rozporządzenia: ursula, kosmicznej, wymagań, green, tajwanem, traktatu, poszczególnych, lösing,
# Nearest to decyzji: arktyki, poniosły, władzami, życzenia, pasażerach, république, wynikiem, sprawie,
# Nearest to zakresie: poignant, zbliżające, pozostałe, część, gallo, planuje, modernizacji, etniczne,
# Nearest to przypadku: ogłoszona, pilnych, romano, większą, république, jakim, korupcją, sehnalová,
# Nearest to których: wnioskami, wypłacanych, kompromisowe, tsunami, dała, projektu, urzędników, zajmuje,
# Nearest to komisji: rady, regularnych, ecr, liberałów, modus, znajdującej, środę, obowiązującym,
# Nearest to rzecz: dba, budżetowego, zgłosi, turystów, wykroczenia, ueindie, obwe, wymienia,
# Nearest to ustęp: instytucjonalnych, krasts, république, zależności, liście, ilość, cope, wfp,
# Nearest to rady: komisji, podzielone, godzinach, rzadkich, daul, ewentualnych, opiekuńczych, 2002882we,
# Nearest to przez: becsey, guidoni, oświadczeniem, siły, wywozem, stara, skazany, trybunał,
# Nearest to 3: sesję, światowym, stanowił, 2200, zaproponowania, zagrożenia, pocztowych, ekonomicznospołeczny,
# Nearest to tym: joly, przystąpi, dyskryminowania, interpretacji, rodi, podejmie, skarżący, jeszcze,
# Nearest to 4: przeciwdziałanie, umożliwić, razem, zaginionych, południu, wywozu, obama, gospodarki,
# Average loss at step  12000 :  9.545994869560003
# Average loss at step  14000 :  10.422080915868282
# Average loss at step  16000 :  7.8228930507600305
# Average loss at step  18000 :  7.479457424074411
# Average loss at step  20000 :  5.827106148540974
# Nearest to r: cornillet, schematu, konstytucją, odwrócić, mówić, włączając, madagaskaru, obejmującej,
# Nearest to de: charles, ekonomicznospołeczny, van, władzom, rolandas, silviu, bélier, punkty,
# Nearest to 2: państwu, prośby, stosowaniu, 3, martina, casaca, religijnych, łańcuchu,
# Nearest to rozporządzenia: dyrektywy, kosmicznej, decyzji, ursula, karną, green, traktatu, nr,
# Nearest to decyzji: rozporządzenia, arktyki, poniosły, władzami, deklaracja, wręcz, ziemniaczanej, życzenia,
# Nearest to zakresie: poignant, zbliżające, sprawie, część, pozostałe, gallo, etniczne, tej,
# Nearest to przypadku: ogłoszona, pilnych, większą, romano, sehnalová, jakim, wydatki, kontekście,
# Nearest to których: wypłacanych, wnioskami, kompromisowe, dała, walutą, tsunami, urzędników, zajmuje,
# Nearest to komisji: rady, regularnych, liberałów, znajdującej, ecr, modus, weryfikacja, polledo,
# Nearest to rzecz: wykroczenia, dba, logiczne, sprawiedliwą, budżetowego, ueindie, zgłosi, mechanizmu,
# Nearest to ustęp: krasts, instytucjonalnych, poprzednim, wfp, zależności, paszport, korupcję, wrażliwych,
# Nearest to rady: komisji, godzinach, podzielone, rzadkich, ewentualnych, 2002882we, daul, ogranicza,
# Nearest to przez: guidoni, becsey, abadjiev, etc, oświadczeniem, ujętych, matthias, skazany,
# Nearest to 3: zajął, 4, światowym, kolegialności, 2, 2200, 5, ekonomicznospołeczny,
# Nearest to tym: joly, przystąpi, dyskryminowania, skarżący, interpretacji, jeszcze, podejmie, podsumowania,
# Nearest to 4: 1011, umożliwić, eł, 15, przeciwdziałanie, razem, 3, nakładają,
# Average loss at step  22000 :  5.781812593087554
# Average loss at step  24000 :  5.495570537224412
# Average loss at step  26000 :  5.064203704550862
# Average loss at step  28000 :  4.4364777579456565
# Average loss at step  30000 :  4.833305157363415
# Nearest to r: cornillet, schematu, konstytucją, roku, mówić, odwrócić, brabant, włączając,
# Nearest to de: van, charles, ekonomicznospołeczny, silviu, pse, władzom, bélier, punkty,
# Nearest to 2: państwu, 3, martina, 4, łańcuchu, zbywalne, religijnych, prośby,
# Nearest to rozporządzenia: dyrektywy, decyzji, nr, kosmicznej, karną, uznawane, ustanawiającej, tajwanem,
# Nearest to decyzji: rozporządzenia, poniosły, dyrektywy, arktyki, władzami, wręcz, życzenia, deklaracja,
# Nearest to zakresie: sprawie, poignant, zbliżające, dziedzinie, tej, pozostałe, część, perfluorooktanu,
# Nearest to przypadku: ogłoszona, imieniu, pilnych, sehnalová, większą, przybrzeżnej, romano, wydatki,
# Nearest to których: wypłacanych, wnioskami, kompromisowe, 2225, 1999468, walutą, tsunami, jeggle,
# Nearest to komisji: rady, regularnych, liberałów, weryfikacja, ecr, nasreen, równorzędne, dyskutowali,
# Nearest to rzecz: wykroczenia, dba, logiczne, ueindie, sprawiedliwą, budżetowego, mechanizmu, terenie,
# Nearest to ustęp: krasts, poprzednim, instytucjonalnych, wfp, korupcję, paszport, wrażliwych, dyscyplinarnym,
# Nearest to rady: komisji, rzadkich, godzinach, parlamentu, kochmehrin, ewentualnych, ogranicza, beazley,
# Nearest to przez: abadjiev, guidoni, pojedynczokadłubowych, gwatemala, ujętych, oświadczeniem, etc, matthias,
# Nearest to 3: 4, 2, 5, zajął, patrzy, kolegialności, 7, 2200,
# Nearest to tym: joly, dyskryminowania, przystąpi, skarżący, interpretacji, jeszcze, negatywna, legislacyjnym,
# Nearest to 4: 3, 8, 1011, 15, umożliwić, eł, nakładają, 11,
# Average loss at step  32000 :  4.636326974779368
# Average loss at step  34000 :  4.341605177938938
# Average loss at step  36000 :  3.7503950526416303
# Average loss at step  38000 :  4.178520791724324
# Average loss at step  40000 :  4.096388354077935
# Nearest to r: roku, cornillet, schematu, mówić, konstytucją, brabant, socjalistyczna, odwrócić,
# Nearest to de: van, charles, pse, silviu, ekonomicznospołeczny, 2000527we, władzom, wytyczonymi,
# Nearest to 2: 3, państwu, 4, przetwórcy, martina, 9, łańcuchu, lepsze,
# Nearest to rozporządzenia: dyrektywy, decyzji, nr, kosmicznej, karną, traktatu, ustanawiającej, tajwanem,
# Nearest to decyzji: rozporządzenia, dyrektywy, poniosły, władzami, wręcz, obowiązku, winnice, deklaracja,
# Nearest to zakresie: sprawie, dziedzinie, poignant, zbliżające, tej, część, potężne, pozostałe,
# Nearest to przypadku: imieniu, ogłoszona, bankami, pilnych, sprawie, sehnalová, przybrzeżnej, normalnych,
# Nearest to których: wypłacanych, 2225, wnioskami, 1999468, guantanamo, jeggle, dochodzeniem, odebraniem,
# Nearest to komisji: rady, regularnych, imco, liberałów, obowiązującym, pokrycia, wszelkimi, weryfikacja,
# Nearest to rzecz: wykroczenia, celu, dba, ueindie, sprawiedliwą, terenie, logiczne, mechanizmu,
# Nearest to ustęp: krasts, poprzednim, instytucjonalnych, dyscyplinarnym, wfp, korupcję, wrażliwych, paszport,
# Nearest to rady: komisji, rzadkich, godzinach, parlamentu, wykluczenie, kochmehrin, ewentualnych, 200183we,
# Nearest to przez: abadjiev, etc, guidoni, pojedynczokadłubowych, gwatemala, oświadczeniem, chronią, umieszczając,
# Nearest to 3: 4, 2, 5, 7, 8, zajął, patrzy, kolegialności,
# Nearest to tym: joly, skarżący, dyskryminowania, przystąpi, interpretacji, jeszcze, interoperacyjności, przyznają,
# Nearest to 4: 3, 8, 1011, 2, 5, 15, eł, nakładają,
# Average loss at step  42000 :  3.6827076913565397
# Average loss at step  44000 :  3.995631938233972
# Average loss at step  46000 :  3.9387468843758104
# Average loss at step  48000 :  3.814999472692609
# Average loss at step  50000 :  3.87213316000998
# Nearest to r: roku, cornillet, grudnia, schematu, mówić, konstytucją, zależało, <unk>,
# Nearest to de: van, charles, silviu, ekonomicznospołeczny, władzom, pse, xml, 2000527we,
# Nearest to 2: 3, 4, 9, państwu, 1, 5, 6, martina,
# Nearest to rozporządzenia: dyrektywy, decyzji, nr, kosmicznej, karną, traktatu, tajwanem, negocjacyjnej,
# Nearest to decyzji: rozporządzenia, dyrektywy, obowiązku, wręcz, władzami, poniosły, życzenia, deklaracja,
# Nearest to zakresie: sprawie, dziedzinie, poignant, zbliżające, imieniu, celu, tej, potężne,
# Nearest to przypadku: imieniu, bankami, ogłoszona, sprawie, pilnych, terminie, przybrzeżnej, sytuacjach,
# Nearest to których: wypłacanych, 1999468, guantanamo, dochodzeniem, 2225, tsunami, kompromisowe, wnioskami,
# Nearest to komisji: rady, regularnych, liechtensteinu, wartościowych, imco, obowiązującym, liberałów, równorzędne,
# Nearest to rzecz: wykroczenia, celu, ueindie, mechanizmu, poziomie, sprawiedliwą, dba, terenie,
# Nearest to ustęp: krasts, poprzednim, instytucjonalnych, dyscyplinarnym, wfp, korupcję, paszport, wrażliwych,
# Nearest to rady: komisji, rzadkich, godzinach, terytorialnego, kochmehrin, 200183we, naukowe, kułakowski,
# Nearest to przez: etc, zrównoważenie, abadjiev, chronią, pojedynczokadłubowych, oświadczeniem, radości, umieszczając,
# Nearest to 3: 2, 4, 5, 7, 8, 6, patrzy, 9,
# Nearest to tym: joly, skarżący, dyskryminowania, przystąpi, interpretacji, przyznają, interoperacyjności, oparciu,
# Nearest to 4: 3, 2, 8, 9, 14, 5, 1011, 6,
# Average loss at step  52000 :  3.8183558153361083
# Average loss at step  54000 :  3.37579945845902
# Average loss at step  56000 :  3.2739455415904524
# Average loss at step  58000 :  3.475193249210715
# Average loss at step  60000 :  3.395457768201828
# Nearest to r: roku, cornillet, mówić, grudnia, francuski, zależało, schematu, prospektu,
# Nearest to de: van, charles, silviu, pse, 2000527we, sprawiedliwej, ekonomicznospołeczny, wytyczonymi,
# Nearest to 2: 3, 4, 9, 1, 5, 6, państwu, 8,
# Nearest to rozporządzenia: dyrektywy, decyzji, nr, kosmicznej, traktatu, 10731999, karną, negocjacyjnej,
# Nearest to decyzji: rozporządzenia, dyrektywy, obowiązku, wręcz, władzami, poniosły, życzenia, 2008we,
# Nearest to zakresie: dziedzinie, sprawie, imieniu, poignant, zbliżające, celu, tej, potężne,
# Nearest to przypadku: imieniu, bankami, sprawie, ogłoszona, sytuacjach, pilnych, terminie, sprawach,
# Nearest to których: wypłacanych, dochodzeniem, guantanamo, 2225, tsunami, 1999468, które, odebraniem,
# Nearest to komisji: regularnych, rady, imco, długi, wartościowych, motywowania, liechtensteinu, liberałów,
# Nearest to rzecz: wykroczenia, celu, ueindie, poziomie, terenie, względu, mechanizmu, sprawiedliwą,
# Nearest to ustęp: krasts, instytucjonalnych, poprzednim, wfp, dyscyplinarnym, korupcję, paszport, wrażliwych,
# Nearest to rady: komisji, 200183we, kochmehrin, parlamentu, rzadkich, naukowe, godzinach, terytorialnego,
# Nearest to przez: zrównoważenie, chronią, etc, abadjiev, nisko, umieszczając, oświadczeniem, radości,
# Nearest to 3: 2, 4, 5, 7, 6, 9, 8, patrzy,
# Nearest to tym: joly, skarżący, dyskryminowania, przystąpi, przyznają, interoperacyjności, obuwia, interpretacji,
# Nearest to 4: 2, 3, 8, 9, 5, 14, 6, 10,
# Average loss at step  62000 :  3.737057539150119
# Average loss at step  64000 :  3.6996398593485353
# Average loss at step  66000 :  3.229691559150815
# Average loss at step  68000 :  3.0247877135276795
# Average loss at step  70000 :  3.511837227597833
# Nearest to r: roku, grudnia, prospektu, schematu, cornillet, socjalistyczna, mówić, uzyskanego,
# Nearest to de: charles, van, silviu, 2000527we, ekonomicznospołeczny, wytyczonymi, pse, transportowym,
# Nearest to 2: 3, 4, 9, 1, 5, 6, 8, 7,
# Nearest to rozporządzenia: dyrektywy, decyzji, nr, kosmicznej, traktatu, karną, 10731999, ustanawiającej,
# Nearest to decyzji: rozporządzenia, dyrektywy, obowiązku, wręcz, 2008we, życzenia, communities, 2001470we,
# Nearest to zakresie: sprawie, dziedzinie, fonogramu, imieniu, poignant, ramach, zbliżające, przewidzianej,
# Nearest to przypadku: imieniu, sprawie, bankami, ogłoszona, terminie, sytuacjach, sprawach, pilnych,
# Nearest to których: wypłacanych, dochodzeniem, guantanamo, 2225, tsunami, którym, które, saharze,
# Nearest to komisji: regularnych, rady, imco, długi, motywowania, liechtensteinu, wartościowych, zamieszkania,
# Nearest to rzecz: wykroczenia, celu, temat, względu, poziomie, ueindie, mechanizmu, sprawiedliwą,
# Nearest to ustęp: krasts, instytucjonalnych, wfp, dyscyplinarnym, poprzednim, korupcję, paszport, wrażliwych,
# Nearest to rady: komisji, 200183we, kochmehrin, godzinach, terytorialnego, naukowe, parlamentu, 12008,
# Nearest to przez: zrównoważenie, etc, nisko, chronią, abadjiev, radości, umieszczając, pojedynczokadłubowych,
# Nearest to 3: 2, 4, 5, 6, 7, 9, 8, 24,
# Nearest to tym: joly, skarżący, dyskryminowania, przyznają, interoperacyjności, przystąpi, oparciu, ostatnim,
# Nearest to 4: 2, 3, 8, 5, 9, 14, 6, 10,
# Average loss at step  72000 :  3.727749515861273
# Average loss at step  74000 :  3.399481726333499
# Average loss at step  76000 :  3.489273474276066
# Average loss at step  78000 :  3.315680021032691
# Average loss at step  80000 :  3.431392376512289
# Nearest to r: roku, grudnia, socjalistyczna, v0en, czerwca, konstytucją, czytaniu, przedsięwzięła,
# Nearest to de: charles, van, silviu, skontaktowania, impress, ekonomicznospołeczny, 2000527we, bélier,
# Nearest to 2: 3, 4, 5, 1, 9, 6, 8, 7,
# Nearest to rozporządzenia: dyrektywy, decyzji, nr, karną, 10731999, kosmicznej, pekinu, traktatu,
# Nearest to decyzji: rozporządzenia, dyrektywy, obowiązku, wręcz, 2008we, róg, poniosły, przedmiotowo,
# Nearest to zakresie: dziedzinie, sprawie, fonogramu, imieniu, ramach, celu, zbliżające, sektorze,
# Nearest to przypadku: imieniu, sprawie, bankami, terminie, sytuacjach, ogłoszona, pilnych, liberalizacją,
# Nearest to których: wypłacanych, dochodzeniem, guantanamo, które, 2225, 1999468, saharze, tsunami,
# Nearest to komisji: rady, imco, regularnych, liberałów, wartościowych, delegacji, radzie, żowtisa,
# Nearest to rzecz: celu, wykroczenia, temat, mechanizmu, względu, poziomie, ueindie, sprawiedliwą,
# Nearest to ustęp: krasts, wfp, instytucjonalnych, dyscyplinarnym, poprzednim, korupcję, paszport, wrażliwych,
# Nearest to rady: komisji, 200183we, godzinach, naukowe, kochmehrin, terytorialnego, parlamentu, rzadkich,
# Nearest to przez: etc, nisko, abadjiev, zrównoważenie, chronią, gwatemala, pojedynczokadłubowych, umieszczając,
# Nearest to 3: 2, 4, 5, 6, 7, 9, 8, 24,
# Nearest to tym: joly, skarżący, dyskryminowania, przyznają, przystąpi, oparciu, interoperacyjności, ostatnim,
# Nearest to 4: 3, 2, 5, 8, 9, 6, 14, 10,
# Average loss at step  82000 :  3.1230899708122015
# Average loss at step  84000 :  3.2510010066628454
# Average loss at step  86000 :  3.212524539411068
# Average loss at step  88000 :  3.090022551164031
# Average loss at step  90000 :  3.0868302893787622
# Nearest to r: roku, grudnia, socjalistyczna, czerwca, v0en, lipca, konstytucją, czytaniu,
# Nearest to de: van, charles, silviu, 2000527we, skontaktowania, bélier, impress, uniezależnienia,
# Nearest to 2: 3, 4, 1, 5, 9, 6, 7, 8,
# Nearest to rozporządzenia: dyrektywy, decyzji, nr, 10731999, kosmicznej, karną, traktatu, pekinu,
# Nearest to decyzji: rozporządzenia, dyrektywy, obowiązku, wręcz, deklaracja, 2008we, rezolucji, 20060322bri06601,
# Nearest to zakresie: sprawie, dziedzinie, fonogramu, imieniu, celu, przewidzianej, ramach, poignant,
# Nearest to przypadku: imieniu, sprawie, bankami, terminie, sytuacjach, sehnalová, pilnych, czytaniu,
# Nearest to których: wypłacanych, dochodzeniem, które, 1999468, guantanamo, saharze, 2225, konwencjonalnej,
# Nearest to komisji: rady, imco, regularnych, obowiązującym, delegacji, radzie, wartościowych, wycofać,
# Nearest to rzecz: temat, wykroczenia, celu, względu, mechanizmu, poziomie, ueindie, osłon,
# Nearest to ustęp: krasts, wfp, instytucjonalnych, korupcję, dyscyplinarnym, poprzednim, osoba, paszport,
# Nearest to rady: komisji, 200183we, godzinach, parlamentu, naukowe, kochmehrin, terytorialnego, tj,
# Nearest to przez: nisko, etc, zrównoważenie, abadjiev, chronią, gwatemala, produkowana, miny,
# Nearest to 3: 2, 4, 5, 6, 7, 9, 8, 10,
# Nearest to tym: joly, skarżący, przyznają, oparciu, dyskryminowania, interoperacyjności, przystąpi, ostatnim,
# Nearest to 4: 3, 2, 5, 8, 9, 6, 14, 10,
# Average loss at step  92000 :  3.0563873945772646
# Average loss at step  94000 :  2.8562956560626627
# Average loss at step  96000 :  3.1114870708733795
# Average loss at step  98000 :  2.828949210897088
# Average loss at step  100000 :  3.0767025324180723
# Nearest to r: roku, grudnia, czerwca, maja, lipca, socjalistyczna, września, budżetowy,
# Nearest to de: van, silviu, charles, impress, kolarskabobińska, bélier, skontaktowania, 2000527we,
# Nearest to 2: 3, 4, 1, 5, 9, 7, 6, 8,
# Nearest to rozporządzenia: dyrektywy, decyzji, nr, 10731999, traktatu, kosmicznej, karną, negocjacyjnej,
# Nearest to decyzji: dyrektywy, rozporządzenia, obowiązku, deklaracja, centralni, wręcz, rezolucji, przedmiotowo,
# Nearest to zakresie: dziedzinie, sprawie, imieniu, fonogramu, ramach, celu, tej, odniesieniu,
# Nearest to przypadku: imieniu, terminie, sprawie, sytuacjach, języku, sehnalová, liberalizacją, bankami,
# Nearest to których: wypłacanych, dochodzeniem, której, 1999468, guantanamo, które, hugo, saharze,
# Nearest to komisji: imco, rady, regularnych, wycofać, długi, obowiązującym, wartościowych, czarne,
# Nearest to rzecz: temat, wykroczenia, względu, mechanizmu, osłon, poziomie, ueindie, celu,
# Nearest to ustęp: krasts, wfp, korupcję, instytucjonalnych, dyscyplinarnym, osoba, poprzednim, 24042007,
# Nearest to rady: 200183we, parlamentu, komisji, godzinach, kochmehrin, wdrażające, tj, naukowe,
# Nearest to przez: nisko, zrównoważenie, produkowana, abadjiev, chronią, etc, gwatemala, umieszczając,
# Nearest to 3: 2, 5, 4, 7, 6, 9, 8, 10,
# Nearest to tym: joly, przyznają, skarżący, oparciu, dyskryminowania, interoperacyjności, wycofana, morris,
# Nearest to 4: 3, 2, 5, 8, 6, 9, 14, 7,
